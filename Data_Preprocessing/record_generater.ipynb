
    "Height": 1.63,
    "Food_category": "Bread",
    "Calories": 265
  },
  {
    "UserId": 1,
    "RecordID": 44,
    "Timestamp": "14/10/2023 12:00",
    "Weight": 52.1,
    "Height": 1.63,
    "Food_category": "Ramen",
    "Calories": 436
  },
  {
    "UserId": 1,
    "RecordID": 45,
    "Timestamp": "14/10/2023 17:10",
    "Weight": 52,
    "Height": 1.63,
    "Food_category": "Hainanese Chicken Rice",
    "Calories": 618
  },
  {
    "UserId": 1,
    "RecordID": 46,
    "Timestamp": "15/10/2023 8:45",
    "Weight": 51.8,
    "Height": 1.63,
    "Food_category": "Bread",
    "Calories": 265
  },
  {
    "UserId": 1,
    "RecordID": 47,
    "Timestamp": "15/10/2023 14:00",
    "Weight": 51.5,
    "Height": 1.63,
    "Food_category": "Ramen",
    "Calories": 436
  },
  {
    "UserId": 1,
    "RecordID": 48,
    "Timestamp": "15/10/2023 18:00",
    "Weight": 51.5,
    "Height": 1.63,
    "Food_category": "Hainanese Chicken Rice",
    "Calories": 618
  },
  {
    "UserId": 1,
    "RecordID": 49,
    "Timestamp": "16/10/2023 9:15",
    "Weight": 50.9,
    "Height": 1.63,
    "Food_category": "Bread",
    "Calories": 265
  },
  {
    "UserId": 1,
    "RecordID": 50,
    "Timestamp": "16/10/2023 11:58",
    "Weight": 50.2,
    "Height": 1.63,
    "Food_category": "Ramen",
    "Calories": 436
  },
  {
    "UserId": 1,
    "RecordID": 51,
    "Timestamp": "16/10/2023 17:00",
    "Weight": 50,
    "Height": 1.63,
    "Food_category": "Hainanese Chicken Rice",
    "Calories": 618
  },
  {
    "UserId": 1,
    "RecordID": 52,
    "Timestamp": "17/10/2023 9:30",
    "Weight": 49.5,
    "Height": 1.63,
    "Food_category": "Bread",
    "Calories": 265
  },
  {
    "UserId": 1,
    "RecordID": 53,
    "Timestamp": "17/10/2023 12:43",
    "Weight": 49.2,
    "Height": 1.63,
    "Food_category": "Ramen",
    "Calories": 436
  },
  {
    "UserId": 1,
    "RecordID": 54,
    "Timestamp": "17/10/2023 17:15",
    "Weight": 49,
    "Height": 1.63,
    "Food_category": "Hainanese Chicken Rice",
    "Calories": 618
  },
  {
    "UserId": 1,
    "RecordID": 55,
    "Timestamp": "18/10/2023 9:20",
    "Weight": 48.5,
    "Height": 1.63,
    "Food_category": "Bread",
    "Calories": 265
  },
  {
    "UserId": 1,
    "RecordID": 56,
    "Timestamp": "18/10/2023 14:14",
    "Weight": 48.2,
    "Height": 1.63,
    "Food_category": "Ramen",
    "Calories": 436
  },
  {
    "UserId": 1,
    "RecordID": 57,
    "Timestamp": "18/10/2023 17:20",
    "Weight": 48.9,
    "Height": 1.63,
    "Food_category": "Hainanese Chicken Rice",
    "Calories": 618
  },
  {
    "UserId": 1,
    "RecordID": 58,
    "Timestamp": "19/10/2023 9:30",
    "Weight": 48.3,
    "Height": 1.63,
    "Food_category": "Bread",
    "Calories": 265
  },
  {
    "UserId": 1,
    "RecordID": 59,
    "Timestamp": "19/10/2023 17:05",
    "Weight": 48.2,
    "Height": 1.63,
    "Food_category": "Ramen",
    "Calories": 436
  },
  {
    "UserId": 1,
    "RecordID": 60,
    "Timestamp": "20/10/2023 9:00",
    "Weight": 48,
    "Height": 1.63,
    "Food_category": "Hainanese Chicken Rice",
    "Calories": 618
  },
  {
    "UserId": 1,
    "RecordID": 61,
    "Timestamp": "20/10/2023 17:20",
    "Weight": 48,
    "Height": 1.63,
    "Food_category": "Bread",
    "Calories": 265
  }
]
'''

# %%
np.random.randint(-10, 10) / 1000
# Out:
# 0.003

# %%
np.random.choice(food_categories)
# Out:
# 'Croissant'

# %%
json.loads(org_json)
# Out:
# [{'UserId': 1,
#   'RecordID': 1,
#   'Timestamp': '1/9/23 8:00',
#   'Weight': 72,
#   'Height': 1.63,
#   'Food_category': 'Bread',
#   'Calories': 265},
#  {'UserId': 1,
#   'RecordID': 2,
#   'Timestamp': '1/9/23 11:00',
#   'Weight': 71.5,
#   'Height': 1.63,
#   'Food_category': 'Ramen',
#   'Calories': 436},
#  {'UserId': 1,
#   'RecordID': 3,
#   'Timestamp': '1/9/23 15:00',
#   'Weight': 71,
#   'Height': 1.63,
#   'Food_category': 'Hainanese Chicken Rice',
#   'Calories': 618},
#  {'UserId': 1,
#   'RecordID': 4,
#   'Timestamp': '2/9/23 7:30',
#   'Weight': 70,
#   'Height': 1.63,
#   'Food_category': 'Bread',
#   'Calories': 265},
#  {'UserId': 1,
#   'RecordID': 5,
#   'Timestamp': '2/9/23 11:15',
#   'Weight': 70.5,
#   'Height': 1.63,
#   'Food_category': 'Ramen',
#   'Calories': 436},
#  {'UserId': 1,
#   'RecordID': 6,
#   'Timestamp': '2/9/23 14:50',
#   'Weight': 70,
#   'Height': 1.63,
#   'Food_category': 'Hainanese Chicken Rice',
#   'Calories': 618},
# ...

# %%
new_json = "[\n"
record_id = 1
weight = 80
height = 1.68
food_categories = [
    'Bread', 'Ramen', 'Noodles', 'Dim Sum', 'Bubble Tea', 'Hainanese Chicken Rice', 'Sashimi Bowl', 'Sushi',
    'Fried Chicken', 'Burger', 'Hot Pot', 'Barbeque', 'Fried Rice', 'Pizza', 'Taco', 'Pasta', 'Waffles', 
    'Hot Dog', 'French Fries', 'Sausages', 'Croissant', 'Ice Cream', 'Pancake', 'Beef Steak', 'Tiramisu',
    'Pad Thai', 'Pho', 'Miso Soup', 'Donuts', 'Cupcake', 'Egg Rolls', 'Gyoza', 'Muffin', 'Bagel', 'Cinnamon Roll',
    'Lasagna', 'Cannoli', 'Churros', 'Chicken Wings', 'Falafel', 'Gyudon', 'Hamburger', 'Jambalaya', 'Kebab', 
    'Lobster', 'Macaroni and Cheese', 'Nachos', 'Omelette', 'Onigiri', 'Poutine', 'Quiche', 'Ravioli', 'Salmon',
    'Tater Tots', 'Udon', 'Vegan Burger', 'Wontons', 'Yakitori', 'Ziti', 'Avocado Toast', 'Baklava', 'Ceviche',
    'Dumplings', 'Enchiladas', 'Fish and Chips', 'Goulash', 'Hash Browns', 'Indian Curry', 'Jerk Chicken', 'Katsu',
    'Linguine', 'Meatballs', 'Naan', 'Oysters', 'Paella', 'Quesadilla', 'Ratatouille', 'Samosa', 'Tzatziki',
    'Vindaloo', 'Wiener Schnitzel', 'Yakisoba', 'Zucchini Noodles', 'Chimichanga', 'Escargot', 'Fajitas', 'Gumbo',
    'Hummus', 'Irish Stew', 'Jollof Rice', 'Kimchi', 'Laksa', 'Moussaka', 'Nasi Goreng', 'Okonomiyaki', 'Pastrami'
]

for month in [9, 10, 11]:
    for day in range(1, 32):
        if (month == 9 or month == 11) and day == 31:
            continue
        if month == 11 and day == 20:
            break
        date = '{}/{}/2023'.format(day, month)
        time1 = '{}:{}'.format(np.random.randint(7,11), str(np.random.randint(0,60)).zfill(2))
        time2 = '{}:{}'.format(np.random.randint(11,14), str(np.random.randint(0,60)).zfill(2))
        time3 = '{}:{}'.format(np.random.randint(15,17), str(np.random.randint(0,60)).zfill(2))
        timestamp1 = date + ' ' + time1
        timestamp2 = date + ' ' + time2
        timestamp3 = date + ' ' + time3
        for timestamp in [timestamp1, timestamp2, timestamp3]:  
            weight += np.random.randint(-3, 2) / 10
            new_json += '   {' + """
        "UserId": 1,
        "RecordID": {},
        "Timestamp": "{}",
        "Weight": {:.1f},
        "Height": {:.2f},
        "Food_category": "{}",
        "Calories": {}
            """.format(record_id, timestamp, weight, height, np.random.choice(food_categories), np.random.randint(10, 100) * 10) + '   },\n'
            record_id += 1
            # print(timestamp1)
            # print(timestamp2)
            # print(timestamp3)
            # if int(time3.split(':')[0]) - int(time1.split(':')[0]) < 8:
            #     print('success')
            # else:
            #     print('fail')
new_json = new_json[:-2] + '\n]'

# %%
print(new_json)
# Out:
# [
#    {
#         "UserId": 1,
#         "RecordID": 1,
#         "Timestamp": "1/9/2023 7:50",
#         "Weight": 79.7,
#         "Height": 1.68,
#         "Food_category": "Linguine",
#         "Calories": 240
#                },
#    {
#         "UserId": 1,
#         "RecordID": 2,
#         "Timestamp": "1/9/2023 13:58",
#         "Weight": 79.6,
#         "Height": 1.68,
#         "Food_category": "Linguine",
#         "Calories": 540
#                },
#    {
#         "UserId": 1,
#         "RecordID": 3,
#         "Timestamp": "1/9/2023 16:10",
#         "Weight": 79.4,
#         "Height": 1.68,
#         "Food_category": "Sausages",
#         "Calories": 690
#                },
#    {
#         "UserId": 1,
#         "RecordID": 4,
#         "Timestamp": "2/9/2023 7:04",
#         "Weight": 79.5,
#         "Height": 1.68,
#         "Food_category": "Egg Rolls",
#         "Calories": 820
#                },
#    {
#         "UserId": 1,
#         "RecordID": 5,
# ...

# %%
json.loads(new_json)
# Out:
# [{'UserId': 1,
#   'RecordID': 1,
#   'Timestamp': '1/9/2023 7:50',
#   'Weight': 79.7,
#   'Height': 1.68,
#   'Food_category': 'Linguine',
#   'Calories': 240},
#  {'UserId': 1,
#   'RecordID': 2,
#   'Timestamp': '1/9/2023 13:58',
#   'Weight': 79.6,
#   'Height': 1.68,
#   'Food_category': 'Linguine',
#   'Calories': 540},
#  {'UserId': 1,
#   'RecordID': 3,
#   'Timestamp': '1/9/2023 16:10',
#   'Weight': 79.4,
#   'Height': 1.68,
#   'Food_category': 'Sausages',
#   'Calories': 690},
#  {'UserId': 1,
#   'RecordID': 4,
#   'Timestamp': '2/9/2023 7:04',
#   'Weight': 79.5,
#   'Height': 1.68,
#   'Food_category': 'Egg Rolls',
#   'Calories': 820},
#  {'UserId': 1,
#   'RecordID': 5,
#   'Timestamp': '2/9/2023 12:09',
#   'Weight': 79.6,
#   'Height': 1.68,
#   'Food_category': 'Hamburger',
#   'Calories': 460},
#  {'UserId': 1,
#   'RecordID': 6,
#   'Timestamp': '2/9/2023 15:13',
#   'Weight': 79.7,
#   'Height': 1.68,
#   'Food_category': 'Ratatouille',
#   'Calories': 580},
# ...

# %%
"""
      {
        "UserId": 1,
        "RecordID": {},
        "Timestamp": "{}",
        "Weight": {:.1f},
        "Height": {:.2f},
        "Food_category": "{}",
        "Calories": {}
      },
            """.format(record_id, timestamp1, weight, height, np.random.choice(food_categories), np.random.randint(10, 100) * 10)
# Out:
# '\n      {\n        "UserId": 1,\n        "RecordID": {},\n        "Timestamp": "{}",\n        "Weight": {:.1f},\n        "Height": {:.2f},\n        "Food_category": "{}",\n        "Calories": {}\n      },\n            '

# %%
'{\n'+"""
        "UserId": 1,
        "RecordID": {},
        "Timestamp": "{}",
        "Weight": {:.1f},
        "Height": {:.2f},
        "Food_category": "{}",
        "Calories": {}
       """.format(1,2,3,4,5,6) + '},'
# Out:
# '{\n\n        "UserId": 1,\n        "RecordID": 1,\n        "Timestamp": "2",\n        "Weight": 3.0,\n        "Height": 4.00,\n        "Food_category": "5",\n        "Calories": 6\n       },'

# %%
'''
{
"abc": 2
"def"
{}, {:.2f}
'''.format('ghi', 10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[129], line 6
#       1 '''
#       2 {}
#       3 "abc": 2
#       4 "def"
#       5 {}, {:.2f}
# ----> 6 '''.format('ghi', 10)
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %%
height
# Out:
# 1.626

# %%
np.random.randint(0,10) # left inclusive right non-inclusive
# Out:
# 6

# %%
'0'.zfill(2)
# Out:
# '00'
